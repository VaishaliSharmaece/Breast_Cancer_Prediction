# %% [markdown]
# ## BREAST CANCER PREDICTION
# ###  VAISHALI SHARMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Breast_cancer.csv')
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
## Target variable
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## PERFORM EDA

# %%
# box plot
for i in df.drop(['diagnosis', 'id'], axis=1).columns:
    sns.boxplot(df.diagnosis,df[i])
    plt.show()

# %%
# Bar plot
for i in df.drop(['diagnosis', 'id'], axis=1).columns:
    sns.barplot(df.diagnosis,df[i])
    plt.show()

# %%
## Histrogram 
df.hist(bins=10, figsize=(20,20))
plt.show()

# %%
## Distribution plot
for i in df.drop(['diagnosis', 'id'], axis=1).columns:
    sns.distplot(df[i])
    plt.show()

# %%
## Aggregation for all numerical columns
df.select_dtypes(include=['float64']).describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.select_dtypes(include=['float64']).sum()
# Out:
# radius_mean                  8038.429000
# texture_mean                10975.810000
# perimeter_mean              52330.380000
# area_mean                  372631.900000
# smoothness_mean                54.829000
# compactness_mean               59.370020
# concavity_mean                 50.526811
# concave points_mean            27.834994
# symmetry_mean                 103.081100
# fractal_dimension_mean         35.731840
# radius_se                     230.542900
# texture_se                    692.389600
# perimeter_se                 1630.787700
# area_se                     22951.798000
# smoothness_se                   4.006317
# compactness_se                 14.497061
# concavity_se                   18.147525
# concave points_se               6.712002
# symmetry_se                    11.688568
# fractal_dimension_se            2.159300
# radius_worst                 9257.169000
# texture_worst               14610.340000
# perimeter_worst             61031.630000
# ...

# %%
## unique values across all numeric columns
for i in df.select_dtypes(include=['float64']).columns:
    print('unique column name:',i)
    print(df[i].unique())
# Out:
# unique column name: radius_mean
# [17.99  20.57  19.69  11.42  20.29  12.45  18.25  13.71  13.    12.46
#  16.02  15.78  19.17  15.85  13.73  14.54  14.68  16.13  19.81  13.54
#  13.08   9.504 15.34  21.16  16.65  17.14  14.58  18.61  15.3   17.57
#  18.63  11.84  17.02  19.27  16.74  14.25  13.03  14.99  13.48  13.44
#  10.95  19.07  13.28  13.17  18.65   8.196 12.05  13.49  11.76  13.64
#  11.94  18.22  15.1   11.52  19.21  14.71  13.05   8.618 10.17   8.598
#   9.173 12.68  14.78   9.465 11.31   9.029 12.78  18.94   8.888 17.2
#  13.8   12.31  16.07  13.53  18.05  20.18  12.86  11.45  13.34  25.22
#  19.1   12.    18.46  14.48  19.02  12.36  14.64  14.62  15.37  13.27
#  13.45  15.06  20.26  12.18   9.787 11.6   14.42  13.61   6.981  9.876
#  10.49  13.11  11.64  22.27  11.34   9.777 12.63  14.26  10.51   8.726
#  11.93   8.95  14.87  17.95  11.41  18.66  24.25  14.5   13.37  13.85
#  19.    19.79  12.19  15.46  16.16  15.71  18.45  12.77  11.71  11.43
# ...

# %%
## drop Duplicates
print('original number of rows in data frame:',df.shape[0])
print('number of rows after dropping duplicates:',df.drop_duplicates().shape[0])
# Out:
# original number of rows in data frame: 569
# number of rows after dropping duplicates: 569

# %% [markdown]
# ### no duplicates in the data

# %%
## Correlation heat map
plt.figure(figsize=(30, 20))
plt.title('Breast Cancer Feature Correlation', fontsize=50, ha='center')
sns.heatmap(df.corr(), annot=True, square='square', fmt='.2g',linewidths=2)

# %% [markdown]
# ## 4. REPLACE OUTLIERS WITH NULL
# if ratio of mean and st.deviation is greater than 3, I have considered them as outlier and replace it with NAN.

# %%
dff=df.select_dtypes(include=['float64'])

dff.mask(dff.sub(dff.mean()).div(dff.std()).abs().gt(3))
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1              NaN
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0              NaN
#
# ...

# %%
dff_nan=dff.mask(dff.sub(dff.mean()).div(dff.std()).abs().gt(3))

# %% [markdown]
# #### count of nan per column

# %%
dff_nan.isnull().sum(axis=0)
# Out:
# radius_mean                 5
# texture_mean                4
# perimeter_mean              7
# area_mean                   8
# smoothness_mean             5
# compactness_mean            9
# concavity_mean              9
# concave points_mean         6
# symmetry_mean               5
# fractal_dimension_mean      7
# radius_se                   7
# texture_se                  9
# perimeter_se                8
# area_se                     6
# smoothness_se               7
# compactness_se             12
# concavity_se                6
# concave points_se           6
# symmetry_se                11
# fractal_dimension_se       10
# radius_worst                6
# texture_worst               4
# perimeter_worst             6
# area_worst                 10
# smoothness_worst            3
# compactness_worst          10
# concavity_worst             7
# concave points_worst        0
# symmetry_worst              9
# fractal_dimension_worst     9
# dtype: int64

# %% [markdown]
# #### fill nan with mean as all are numerical value and percentage of nan is less then 10% for each column

# %%
dff_nan = dff_nan.fillna(dff_nan.mean())

# %%
dff_nan.isnull().sum(axis=0)
# Out:
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %% [markdown]
# ##  5. Calculation of Z Score

# %% [markdown]
#  #### while calculating the Z-score we re-scale and center the data and look for data points which are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# We will use Z-score function defined in scipy library to detect the outliers.

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(dff_nan))
print(z)
# Out:
# [[1.19964933 2.15220944 1.42636611 ... 2.29607613 3.27196665 2.32220284]
#  [1.97838309 0.34483901 1.87821816 ... 1.0870843  0.21038717 0.39835593]
#  [1.71276847 0.5062637  1.74847846 ... 1.95500035 1.41320621 0.30564042]
#  ...
#  [0.78009897 2.17667507 0.77766762 ... 0.41406869 1.21125818 0.29829814]
#  [1.98743813 2.48238725 2.20033051 ... 2.28998549 2.3049597  2.65057028]
#  [1.88812057 1.31089817 1.92360238 ... 1.74506282 0.01725454 0.80115103]]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([  0,   0,   0,   0,   0,   0,   3,   3,   3,   9,   9,   9,  12,
#         12,  15,  15,  18,  22,  26,  33,  38,  38,  42,  42,  42,  60,
#         62,  63,  68,  68,  68,  72,  77,  78,  78,  78,  78,  78,  82,
#         82,  83, 108, 108, 108, 108, 108, 108, 112, 112, 116, 122, 122,
#        138, 138, 145, 147, 151, 152, 161, 164, 164, 168, 173, 176, 185,
#        190, 190, 190, 199, 202, 202, 202, 212, 212, 212, 214, 214, 219,
#        236, 236, 236, 236, 242, 245, 245, 250, 250, 252, 252, 258, 258,
#        258, 265, 265, 272, 272, 272, 272, 288, 288, 290, 290, 300, 300,
#        302, 302, 314, 318, 329, 332, 339, 339, 339, 351, 352, 368, 368,
#        368, 369, 376, 376, 379, 388, 389, 391, 393, 400, 400, 416, 417,
#        430, 468, 468, 469, 471, 485, 485, 485, 489, 503, 504, 505, 505,
#        505, 520, 520, 520, 521, 521, 521, 521, 528, 528, 539, 563, 563,
# ...

# %% [markdown]
# ## We still have outliers based on your defination of outliers

# %% [markdown]
# ### 6. There are no formatting issues with this data, because we have all the numerical values except 1, hence data is already a cleaned data

# %% [markdown]
# ### 7. Enhancement of EDA is done above with pandas profiling. Grouping of data is not possible as all are numerical values

# %% [markdown]
# ## MACHINE LEARNING -CLASSIFICATON PROBLEM PREDICTION MODEL

# %%
#8 Classification ML
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score, KFold
from sklearn import metrics
from sklearn.metrics import roc_auc_score

# %%
df.diagnosis = df.diagnosis.map({'M':0,'B':1})

# %%
from sklearn.ensemble import RandomForestClassifier

X = df.drop(['diagnosis','id'],axis=1)
y = df[['diagnosis']]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)
model = RandomForestClassifier(n_estimators=100,
                               random_state=101,
                               class_weight='balanced')

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=101,
#                        verbose=0, warm_start=False)

# %%
y_pred = model.predict(X_test)
print('AUC-ROC Score :',roc_auc_score(y_test, y_pred))
print('F1-Score :',f1_score(y_test,y_pred))
print('Report:\n',classification_report(y_test, y_pred))
print('confusion Matrix:\n',confusion_matrix(y_pred,y_test))
# Out:
# AUC-ROC Score : 0.9669312169312169
# F1-Score : 0.9769585253456222
# Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        63
#            1       0.97      0.98      0.98       108
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# confusion Matrix:
#  [[ 60   2]
#  [  3 106]]

# %%
print('cross validation:',cross_val_score(model, X, y, cv=5).mean())
# Out:
# cross validation: 0.9596180717279925

# %%
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

# %%
models = {'RandomForestClassifier':RandomForestClassifier(),
          'LogisitcRegression':LogisticRegression(),
          'GradientBoosingClassifier':GradientBoostingClassifier(),
          'XGBoost':XGBClassifier()}
mn = []
auc = []
f1 = []
acc = []
for model_name, model in models.items():
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    print('\nF1 Score For', model_name,'>>',f1_score(y_test,pred))
    print('AUC-ROC Score :',model_name,'>>',roc_auc_score(y_test, pred))
    print('Report:\n',model_name,'>>',classification_report(y_test, pred))
    print('confusion Matrix:\n',model_name,'>>',confusion_matrix(pred,y_test))
    print('cross validation for',model_name,'::>',cross_val_score(model, X, y, cv=5).mean())
# Out:
# F1 Score For RandomForestClassifier >> 0.9724770642201834
# AUC-ROC Score : RandomForestClassifier >> 0.958994708994709
# Report:
#  RandomForestClassifier >>               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        63
#            1       0.96      0.98      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# confusion Matrix:
#  RandomForestClassifier >> [[ 59   2]
#  [  4 106]]
# cross validation for RandomForestClassifier ::> 0.9964912280701753
#
# F1 Score For LogisitcRegression >> 0.9771689497716894
# AUC-ROC Score : LogisitcRegression >> 0.9636243386243386
# Report:
#  LogisitcRegression >>               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        63
#            1       0.96      0.99      0.98       108
#
# ...

# %% [markdown]
# ## XGBoost Clasifier is the best model to predict the breast cancer as it has the highest accuracy among all the models i.e. 0.98.

# %% [markdown]
# ### Hyper parameter tuning

# %%
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
models = {'RandomForestClassifier':RandomForestClassifier(),
          'GradientBoosingClassifier':GradientBoostingClassifier(),
          'XGBoost':XGBClassifier()}
params = {
            'max_depth': [30, 40, 50],
            'n_estimators': [20, 30, 40, 50, 100],
}
for model_name, model in models.items():
    grid = GridSearchCV(model, params)
    grid.fit(X_train,y_train)
    y_pred = grid.best_estimator_.predict(X_test)
    print('Scores after HypterParameterTuninig')
    print(model_name,' F1-Score is >> :',f1_score(y_test,y_pred))
# Out:
# Scores after HypterParameterTuninig
# RandomForestClassifier  F1-Score is >> : 0.9724770642201834
# Scores after HypterParameterTuninig
# GradientBoosingClassifier  F1-Score is >> : 0.9528301886792453
# Scores after HypterParameterTuninig
# XGBoost  F1-Score is >> : 0.9861751152073732

# %% [markdown]
# ## after hyperpaarmeter tunning the f1 score of XGBoost classifier is enhanced and is 0.98

# %% [markdown]
# ###  PREDICT THE TARGET WITH MAXMIUM INDEPENDENT VARIABLES AND FEATURE IMPORTANCE

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

# plot feature importance
plot_importance(model)
plt.show()

# %%
for col,score in zip(X_train.columns,model.feature_importances_):

    print(col,score)
# Out:
# radius_mean 0.006540067
# texture_mean 0.010556399
# perimeter_mean 0.041885424
# area_mean 0.024673596
# smoothness_mean 0.003542185
# compactness_mean 0.0009887575
# concavity_mean 0.00043077196
# concave points_mean 0.33420268
# symmetry_mean 0.0
# fractal_dimension_mean 0.0016534586
# radius_se 0.018701497
# texture_se 0.005560752
# perimeter_se 0.018609252
# area_se 0.007935484
# smoothness_se 0.0018121066
# compactness_se 0.004697173
# concavity_se 0.023237176
# concave points_se 0.0010539015
# symmetry_se 0.002888682
# fractal_dimension_se 0.015602233
# radius_worst 0.04514629
# texture_worst 0.029781193
# perimeter_worst 0.062357754
# area_worst 0.03739161
# smoothness_worst 0.005156071
# compactness_worst 0.007725505
# concavity_worst 0.012524258
# concave points_worst 0.25772822
# symmetry_worst 0.0056409743
# fractal_dimension_worst 0.011976572

# %%
from numpy import sort
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score

thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(X_test)
    y_pred = selection_model.predict(select_X_test)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, y_pred)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# Thresh=0.000, n=30, Accuracy: 98.25%
# Thresh=0.000, n=29, Accuracy: 98.25%
# Thresh=0.001, n=28, Accuracy: 98.25%
# Thresh=0.001, n=27, Accuracy: 98.25%
# Thresh=0.002, n=26, Accuracy: 98.25%
# Thresh=0.002, n=25, Accuracy: 98.25%
# Thresh=0.003, n=24, Accuracy: 98.25%
# Thresh=0.004, n=23, Accuracy: 98.25%
# Thresh=0.005, n=22, Accuracy: 98.25%
# Thresh=0.005, n=21, Accuracy: 97.66%
# Thresh=0.006, n=20, Accuracy: 97.66%
# Thresh=0.006, n=19, Accuracy: 97.66%
# Thresh=0.007, n=18, Accuracy: 97.66%
# Thresh=0.008, n=17, Accuracy: 97.66%
# Thresh=0.008, n=16, Accuracy: 97.66%
# Thresh=0.011, n=15, Accuracy: 97.66%
# Thresh=0.012, n=14, Accuracy: 96.49%
# Thresh=0.013, n=13, Accuracy: 95.91%
# Thresh=0.016, n=12, Accuracy: 97.08%
# Thresh=0.019, n=11, Accuracy: 97.66%
# Thresh=0.019, n=10, Accuracy: 97.66%
# Thresh=0.023, n=9, Accuracy: 96.49%
# Thresh=0.025, n=8, Accuracy: 97.08%
# Thresh=0.030, n=7, Accuracy: 96.49%
# Thresh=0.037, n=6, Accuracy: 96.49%
# ...

# %%
df_select = df[['area_mean', 'smoothness_mean',
       'concave points_mean', 'area_se', 'symmetry_se',
       'texture_worst','area_worst', 'concavity_worst',
       'symmetry_worst', ]]

# %%
X = df.drop(['diagnosis','id'],axis=1)
y = df[['diagnosis']]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=42)

# %%
models = {'RandomForestClassifier':RandomForestClassifier(),
          'LogisitcRegression':LogisticRegression(),
          'GradientBoosingClassifier':GradientBoostingClassifier(),
          'XGBoost':XGBClassifier()}
mn = []
auc = []
f1 = []
acc = []
for model_name, model in models.items():
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    print('\nF1 Score For', model_name,'>>',f1_score(y_test,pred))
    print('AUC-ROC Score :',model_name,'>>',roc_auc_score(y_test, pred))
    print('Report:\n',model_name,'>>',classification_report(y_test, pred))
    print('confusion Matrix:\n',model_name,'>>',confusion_matrix(pred,y_test))
    print('cross validation for',model_name,'::>',cross_val_score(model, X, y, cv=5).mean())
# Out:
# F1 Score For RandomForestClassifier >> 0.9724770642201834
# AUC-ROC Score : RandomForestClassifier >> 0.958994708994709
# Report:
#  RandomForestClassifier >>               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        63
#            1       0.96      0.98      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# confusion Matrix:
#  RandomForestClassifier >> [[ 59   2]
#  [  4 106]]
# cross validation for RandomForestClassifier ::> 0.9613414066138798
#
# F1 Score For LogisitcRegression >> 0.9771689497716894
# AUC-ROC Score : LogisitcRegression >> 0.9636243386243386
# Report:
#  LogisitcRegression >>               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96        63
#            1       0.96      0.99      0.98       108
#
# ...

# %% [markdown]
# ## With this feature importance we get to know that in future when these models are picked up , then we dont need to run the model on all the variables only those top 10 parameters are enough to predict the cancer as we have seen that with these 10 parameters also the accuracy remains the same.
